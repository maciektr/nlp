# %%
from main import CorpusProcessor

# %%
CorpusProcessor().process()
# Out:
# {'all': BillStats(acts_not_changed=23996,
#                   acts_with_day=8587,
#                   acts_without_day=16347,
#                   acts=24934,
#                   additions=5929,
#                   changes=8688,
#                   removals=2220,
#                   year=None),
#  'by_year': [BillStats(acts_not_changed=170,
#                        acts_with_day=50,
#                        acts_without_day=125,
#                        acts=175,
#                        additions=36,
#                        changes=62,
#                        removals=22,
#                        year='1993'),
#              BillStats(acts_not_changed=502,
#                        acts_with_day=156,
#                        acts_without_day=376,
#                        acts=532,
#                        additions=86,
#                        changes=76,
#                        removals=47,
#                        year='1994'),
#              BillStats(acts_not_changed=3136,
# ...

# %%
acts_with_day=8587
acts_without_day=16347
acts=24934
acts == acts_with_day + acts_without_day
# Out:
# True
